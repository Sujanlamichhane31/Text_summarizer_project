# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pip install transformers[sentencepiece] datasets sacrebleu rouge_score py7zr -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyzstd (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [34 lines of output]
#       C:\Users\Dell\AppData\Local\Temp\pip-build-env-n08q088r\overlay\Lib\site-packages\setuptools\_distutils\dist.py:268: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-38
#       creating build\lib.win-amd64-cpython-38\pyzstd
#       copying src\seekable_zstdfile.py -> build\lib.win-amd64-cpython-38\pyzstd
#       copying src\zstdfile.py -> build\lib.win-amd64-cpython-38\pyzstd
#       copying src\__init__.py -> build\lib.win-amd64-cpython-38\pyzstd
#       copying src\__main__.py -> build\lib.win-amd64-cpython-38\pyzstd
#       creating build\lib.win-amd64-cpython-38\pyzstd\c
#       copying src\c\__init__.py -> build\lib.win-amd64-cpython-38\pyzstd\c
#       copying src\__init__.pyi -> build\lib.win-amd64-cpython-38\pyzstd
#       copying src\py.typed -> build\lib.win-amd64-cpython-38\pyzstd
#       running build_ext
#       +--------------------------------------------+
#       |             Pyzstd build config            |
#       +-------------------------+------------------+
#       | Pyzstd version          | 0.16.2           |
#       +-------------------------+------------------+
#       | Implementation          | C                |
#       +-------------------------+------------------+
#       | Link to zstd library    | Statically link  |
#       +-------------------------+------------------+
#       | Enable AVX2/BMI2        | False            |
#       +-------------------------+------------------+
#       | Debug build             | False            |
#       +-------------------------+------------------+
#       | Warning as error        | False            |
#       +-------------------------+------------------+
#       building 'pyzstd.c._zstd' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pyzstd
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pyzstd)

# %%
# !pip install --upgrade accelerate
# !pip uninstall -y transformers accelerate
# !pip install transformers accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in c:\users\dell\.conda\envs\textsum\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\dell\.conda\envs\textsum\lib\site-packages (from accelerate) (6.0.2)
# Collecting torch>=1.10.0 (from accelerate)
#   Using cached torch-2.4.1-cp38-cp38-win_amd64.whl.metadata (27 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Using cached huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Collecting filelock (from huggingface-hub>=0.21.0->accelerate)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.21.0->accelerate)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting requests (from huggingface-hub>=0.21.0->accelerate)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.42.1 (from huggingface-hub>=0.21.0->accelerate)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (4.11.0)
# Collecting sympy (from torch>=1.10.0->accelerate)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.10.0->accelerate)
#   Using cached networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting jinja2 (from torch>=1.10.0->accelerate)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: colorama in c:\users\dell\.conda\envs\textsum\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.21.0->accelerate) (0.4.6)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.10.0->accelerate)
#   Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
# Collecting charset-normalizer<4,>=2 (from requests->huggingface-hub>=0.21.0->accelerate)
#   Using cached charset_normalizer-3.4.1-cp38-cp38-win_amd64.whl.metadata (36 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub>=0.21.0->accelerate)
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->huggingface-hub>=0.21.0->accelerate)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.10.0->accelerate)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading accelerate-1.0.1-py3-none-any.whl (330 kB)
# Using cached huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
# Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
# Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Using cached torch-2.4.1-cp38-cp38-win_amd64.whl (199.4 MB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.2 MB 2.4 MB/s eta 0:00:03
#    -------- ------------------------------- 1.3/6.2 MB 3.4 MB/s eta 0:00:02
#    --------------- ------------------------ 2.4/6.2 MB 3.7 MB/s eta 0:00:02
#    ------------------ --------------------- 2.9/6.2 MB 3.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.2 MB 3.6 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.2 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.2 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 3.2 MB/s eta 0:00:00
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp38-cp38-win_amd64.whl (102 kB)
# Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl (17 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Installing collected packages: mpmath, urllib3, tqdm, sympy, safetensors, numpy, networkx, MarkupSafe, fsspec, filelock, charset-normalizer, certifi, requests, jinja2, torch, huggingface-hub, accelerate
# Successfully installed MarkupSafe-2.1.5 accelerate-1.0.1 certifi-2025.1.31 charset-normalizer-3.4.1 filelock-3.16.1 fsspec-2025.3.0 huggingface-hub-0.29.3 jinja2-3.1.6 mpmath-1.3.0 networkx-3.1 numpy-1.24.4 requests-2.32.3 safetensors-0.5.3 sympy-1.13.3 torch-2.4.1 tqdm-4.67.1 urllib3-2.2.3
# Found existing installation: accelerate 1.0.1
# Uninstalling accelerate-1.0.1:
#   Successfully uninstalled accelerate-1.0.1
# WARNING: Skipping transformers as it is not installed.
# Collecting transformers
#   Using cached transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Collecting accelerate
#   Using cached accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2024.11.6-cp38-cp38-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers)
#   Using cached tokenizers-0.20.3-cp38-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in c:\users\dell\.conda\envs\textsum\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from accelerate) (2.4.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: sympy in c:\users\dell\.conda\envs\textsum\lib\site-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in c:\users\dell\.conda\envs\textsum\lib\site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.6)
# Requirement already satisfied: colorama in c:\users\dell\.conda\envs\textsum\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Using cached transformers-4.46.3-py3-none-any.whl (10.0 MB)
# Using cached accelerate-1.0.1-py3-none-any.whl (330 kB)
# Using cached regex-2024.11.6-cp38-cp38-win_amd64.whl (274 kB)
# Using cached tokenizers-0.20.3-cp38-none-win_amd64.whl (2.4 MB)
# Installing collected packages: regex, tokenizers, accelerate, transformers
# Successfully installed accelerate-1.0.1 regex-2024.11.6 tokenizers-0.20.3 transformers-4.46.3

# %%
pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Using cached datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from evaluate) (1.24.4)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from evaluate)
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: requests>=2.19.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from evaluate) (4.67.1)
# Collecting xxhash (from evaluate)
#   Using cached xxhash-3.5.0-cp38-cp38-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.17-py38-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from evaluate) (0.29.3)
# Requirement already satisfied: packaging in c:\users\dell\.conda\envs\textsum\lib\site-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in c:\users\dell\.conda\envs\textsum\lib\site-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Collecting pyarrow>=15.0.0 (from datasets>=2.0.0->evaluate)
#   Using cached pyarrow-17.0.0-cp38-cp38-win_amd64.whl.metadata (3.4 kB)
# Collecting dill (from evaluate)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate)
#   Using cached multiprocess-0.70.16-py38-none-any.whl.metadata (7.1 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in c:\users\dell\.conda\envs\textsum\lib\site-packages (from datasets>=2.0.0->evaluate) (3.10.11)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests>=2.19.0->evaluate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests>=2.19.0->evaluate) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\dell\.conda\envs\textsum\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from pandas->evaluate) (2.8.2)
# Collecting pytz>=2020.1 (from pandas->evaluate)
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas->evaluate)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (5.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.0.0->evaluate) (0.2.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
# Using cached datasets-3.1.0-py3-none-any.whl (480 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Using cached multiprocess-0.70.16-py38-none-any.whl (132 kB)
# Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
# Using cached xxhash-3.5.0-cp38-cp38-win_amd64.whl (30 kB)
# Using cached pyarrow-17.0.0-cp38-cp38-win_amd64.whl (25.2 MB)
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, xxhash, tzdata, pyarrow, fsspec, dill, pandas, multiprocess, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# Successfully installed datasets-3.1.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 pandas-2.0.3 pyarrow-17.0.0 pytz-2025.1 tzdata-2025.1 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install transformers datasets evaluate nltk torch tqdm matplotlib pandas
# Out:
# Requirement already satisfied: transformers in c:\users\dell\.conda\envs\textsum\lib\site-packages (4.46.3)
# Requirement already satisfied: datasets in c:\users\dell\.conda\envs\textsum\lib\site-packages (3.1.0)
# Requirement already satisfied: evaluate in c:\users\dell\.conda\envs\textsum\lib\site-packages (0.4.3)
# Collecting nltk
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: torch in c:\users\dell\.conda\envs\textsum\lib\site-packages (2.4.1)
# Requirement already satisfied: tqdm in c:\users\dell\.conda\envs\textsum\lib\site-packages (4.67.1)
# Requirement already satisfied: matplotlib in c:\users\dell\.conda\envs\textsum\lib\site-packages (3.7.5)
# Requirement already satisfied: pandas in c:\users\dell\.conda\envs\textsum\lib\site-packages (2.0.3)
# Requirement already satisfied: filelock in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\dell\.conda\envs\textsum\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in c:\users\dell\.conda\envs\textsum\lib\site-packages (from datasets) (3.10.11)
# Collecting click (from nltk)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\dell\.conda\envs\textsum\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\dell\.conda\envs\textsum\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: colorama in c:\users\dell\.conda\envs\textsum\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\dell\.conda\envs\textsum\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Installing collected packages: joblib, click, nltk
# Successfully installed click-8.1.8 joblib-1.4.2 nltk-3.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline, set_seed
from datasets import load_dataset, load_from_disk
import matplotlib.pyplot as plt
from datasets import load_dataset
import pandas as pd
from datasets import load_dataset
from evaluate import load as load_metrics

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

import nltk
from nltk.tokenize import sent_tokenize

from tqdm import tqdm
import torch

nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
model_ckpt = "google/pegasus-cnn_dailymail"

tokenizer = AutoTokenizer.from_pretrained(model_ckpt)

model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(model_ckpt).to(device)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\convert_slow_tokenizer.py:1496, in TikTokenConverter.extract_vocab_merges_from_model(self, tiktoken_url)
#    1495 try:
# -> 1496     from tiktoken.load import load_tiktoken_bpe
#    1497 except Exception:
#
# ModuleNotFoundError: No module named 'tiktoken'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\convert_slow_tokenizer.py:1633, in convert_slow_tokenizer(transformer_tokenizer, from_tiktoken)
#    1632     logger.info("Converting from Tiktoken")
# -> 1633     return TikTokenConverter(
#    1634         vocab_file=transformer_tokenizer.vocab_file,
#    1635         additional_special_tokens=transformer_tokenizer.additional_special_tokens,
#    1636     ).converted()
#    1637 except Exception:
#
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\convert_slow_tokenizer.py:1533, in TikTokenConverter.converted(self)
#    1532 def converted(self) -> Tokenizer:
# -> 1533     tokenizer = self.tokenizer()
#    1534     tokenizer.pre_tokenizer = pre_tokenizers.Sequence(
#    1535         [
#    1536             pre_tokenizers.Split(Regex(self.pattern), behavior="isolated", invert=False),
#    1537             pre_tokenizers.ByteLevel(add_prefix_space=self.add_prefix_space, use_regex=False),
#    1538         ]
#    1539     )
#
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\convert_slow_tokenizer.py:1526, in TikTokenConverter.tokenizer(self)
#    1525 def tokenizer(self):
# -> 1526     vocab_scores, merges = self.extract_vocab_merges_from_model(self.vocab_file)
#    1527     tokenizer = Tokenizer(BPE(vocab_scores, merges, fuse_unk=False))
#
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\convert_slow_tokenizer.py:1498, in TikTokenConverter.extract_vocab_merges_from_model(self, tiktoken_url)
#    1497 except Exception:
# -> 1498     raise ValueError(
#    1499         "`tiktoken` is required to read a `tiktoken` file. Install it with " "`pip install tiktoken`."
#    1500     )
#    1502 bpe_ranks = load_tiktoken_bpe(tiktoken_url)
#
# ValueError: `tiktoken` is required to read a `tiktoken` file. Install it with `pip install tiktoken`.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\tokenization_utils_base.py:2447, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2446 try:
# -> 2447     tokenizer = cls(*init_inputs, **init_kwargs)
#    2448 except import_protobuf_decode_error():
#
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\models\pegasus\tokenization_pegasus_fast.py:136, in PegasusTokenizerFast.__init__(self, vocab_file, tokenizer_file, pad_token, eos_token, unk_token, mask_token, mask_token_sent, additional_special_tokens, offset, **kwargs)
#     134 kwargs.pop("added_tokens_decoder", {})
# --> 136 super().__init__(
#     137     vocab_file,
#     138     tokenizer_file=tokenizer_file,
#     139     pad_token=pad_token,
#     140     eos_token=eos_token,
#     141     unk_token=unk_token,
#     142     mask_token=mask_token,
#     143     mask_token_sent=mask_token_sent,
#     144     offset=offset,
#     145     additional_special_tokens=additional_special_tokens,
#     146     from_slow=from_slow,
#     147     **kwargs,
#     148 )
#     149 self.vocab_file = vocab_file
#
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\tokenization_utils_fast.py:138, in PreTrainedTokenizerFast.__init__(self, *args, **kwargs)
#     137 self.additional_special_tokens = kwargs.get("additional_special_tokens", [])
# --> 138 fast_tokenizer = convert_slow_tokenizer(self, from_tiktoken=True)
#     139 slow_tokenizer = None
#
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\convert_slow_tokenizer.py:1638, in convert_slow_tokenizer(transformer_tokenizer, from_tiktoken)
#    1637 except Exception:
# -> 1638     raise ValueError(
#    1639         f"Converting from Tiktoken failed, if a converter for SentencePiece is available, provide a model path "
#    1640         f"with a SentencePiece tokenizer.model file."
#    1641         f"Currently available slow->fast convertors: {list(SLOW_TO_FAST_CONVERTERS.keys())}"
#    1642     )
#
# ValueError: Converting from Tiktoken failed, if a converter for SentencePiece is available, provide a model path with a SentencePiece tokenizer.model file.Currently available slow->fast convertors: ['AlbertTokenizer', 'BartTokenizer', 'BarthezTokenizer', 'BertTokenizer', 'BigBirdTokenizer', 'BlenderbotTokenizer', 'CamembertTokenizer', 'CLIPTokenizer', 'CodeGenTokenizer', 'ConvBertTokenizer', 'DebertaTokenizer', 'DebertaV2Tokenizer', 'DistilBertTokenizer', 'DPRReaderTokenizer', 'DPRQuestionEncoderTokenizer', 'DPRContextEncoderTokenizer', 'ElectraTokenizer', 'FNetTokenizer', 'FunnelTokenizer', 'GPT2Tokenizer', 'HerbertTokenizer', 'LayoutLMTokenizer', 'LayoutLMv2Tokenizer', 'LayoutLMv3Tokenizer', 'LayoutXLMTokenizer', 'LongformerTokenizer', 'LEDTokenizer', 'LxmertTokenizer', 'MarkupLMTokenizer', 'MBartTokenizer', 'MBart50Tokenizer', 'MPNetTokenizer', 'MobileBertTokenizer', 'MvpTokenizer', 'NllbTokenizer', 'OpenAIGPTTokenizer', 'PegasusTokenizer', 'Qwen2Tokenizer', 'RealmTokenizer', 'ReformerTokenizer', 'RemBertTokenizer', 'RetriBertTokenizer', 'RobertaTokenizer', 'RoFormerTokenizer', 'SeamlessM4TTokenizer', 'SqueezeBertTokenizer', 'T5Tokenizer', 'UdopTokenizer', 'WhisperTokenizer', 'XLMRobertaTokenizer', 'XLNetTokenizer', 'SplinterTokenizer', 'XGLMTokenizer', 'LlamaTokenizer', 'CodeLlamaTokenizer', 'GemmaTokenizer', 'Phi3Tokenizer']
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 3
#       1 model_ckpt = "google/pegasus-cnn_dailymail"
# ----> 3 tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
#       5 model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(model_ckpt).to(device)
#
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\models\auto\tokenization_auto.py:939, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     936 tokenizer_class_py, tokenizer_class_fast = TOKENIZER_MAPPING[type(config)]
#     938 if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# --> 939     return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     940 else:
#     941     if tokenizer_class_py is not None:
#
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\tokenization_utils_base.py:2213, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2210     else:
#    2211         logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
# -> 2213 return cls._from_pretrained(
#    2214     resolved_vocab_files,
#    2215     pretrained_model_name_or_path,
#    2216     init_configuration,
#    2217     *init_inputs,
#    2218     token=token,
#    2219     cache_dir=cache_dir,
#    2220     local_files_only=local_files_only,
#    2221     _commit_hash=commit_hash,
#    2222     _is_local=is_local,
#    2223     trust_remote_code=trust_remote_code,
#    2224     **kwargs,
#    2225 )
#
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\tokenization_utils_base.py:2448, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2446 try:
#    2447     tokenizer = cls(*init_inputs, **init_kwargs)
# -> 2448 except import_protobuf_decode_error():
#    2449     logger.info(
#    2450         "Unable to load tokenizer model from SPM, loading from TikToken will be attempted instead."
#    2451         "(Google protobuf error: Tried to load SPM model with non-SPM vocab file).",
#    2452     )
#    2453     return False
#
# File c:\Users\Dell\.conda\envs\textSum\lib\site-packages\transformers\tokenization_utils_base.py:87, in import_protobuf_decode_error(error_message)
#      85     return DecodeError
#      86 else:
# ---> 87     raise ImportError(PROTOBUF_IMPORT_ERROR.format(error_message))
#
# ImportError:
#  requires the protobuf library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/protocolbuffers/protobuf/tree/master/python#installation and follow the ones
# that match your environment. Please note that you may need to restart your runtime after installation.

# %%
# !wget --header="Authorization: token {apikey}" \
https://github.com/Sujanlamichhane31/Text_summarizer_project/raw/main/summarizer-data.zip
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !unzip summarizer-data.zip
# Out:
# Archive:  summarizer-data.zip
#   inflating: samsum-test.csv
#   inflating: samsum-train.csv
#   inflating: samsum-validation.csv
#    creating: samsum_dataset/
#  extracting: samsum_dataset/dataset_dict.json
#    creating: samsum_dataset/test/
#   inflating: samsum_dataset/test/data-00000-of-00001.arrow
#   inflating: samsum_dataset/test/dataset_info.json
#   inflating: samsum_dataset/test/state.json
#    creating: samsum_dataset/train/
#   inflating: samsum_dataset/train/data-00000-of-00001.arrow
#   inflating: samsum_dataset/train/dataset_info.json
#   inflating: samsum_dataset/train/state.json
#    creating: samsum_dataset/validation/
#   inflating: samsum_dataset/validation/data-00000-of-00001.arrow
#   inflating: samsum_dataset/validation/dataset_info.json
#   inflating: samsum_dataset/validation/state.json

# %%
dataset_samsum = load_from_disk('samsum_dataset')

# %%
dataset_samsum
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 14732
#     })
#     test: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 819
#     })
#     validation: Dataset({
#         features: ['id', 'dialogue', 'summary'],
#         num_rows: 818
#     })
# })

# %%
split_length = [len(dataset_samsum[split]) for split in dataset_samsum]

print(f"Split lengths: {split_length}")
print(f"Features: {dataset_samsum['train'].column_names}")
print("\nDialogue: ")

print(dataset_samsum["test"][1]["dialogue"])

print("\n Summary: ")

print(dataset_samsum["test"][1]["summary"])
# Out:
# Split lengths: [14732, 819, 818]
# Features: ['id', 'dialogue', 'summary']
#
# Dialogue:
# Eric: MACHINE!
# Rob: That's so gr8!
# Eric: I know! And shows how Americans see Russian ;)
# Rob: And it's really funny!
# Eric: I know! I especially like the train part!
# Rob: Hahaha! No one talks to the machine like that!
# Eric: Is this his only stand-up?
# Rob: Idk. I'll check.
# Eric: Sure.
# Rob: Turns out no! There are some of his stand-ups on youtube.
# Eric: Gr8! I'll watch them now!
# Rob: Me too!
# Eric: MACHINE!
# Rob: MACHINE!
# Eric: TTYL?
# Rob: Sure :)
#
#  Summary:
# Eric and Rob are going to watch a stand-up on youtube.

# %%
def convert_examples_to_features(example_batch):
  input_encodings = tokenizer(example_batch['dialogue'] , max_length=1024, truncation= True)

  with tokenizer.as_target_tokenizer():
    target_encodings = tokenizer(example_batch['summary'], max_length=1024, truncation=True)

  return {
      "input_ids": input_encodings['input_ids'],
      "attention_mask": input_encodings["attention_mask"],
      "labels": target_encodings["input_ids"]
  }

# %%
dataset_samsum_pt = dataset_samsum.map(convert_examples_to_features, batched= True)
# Out:
# Map:   0%|          | 0/14732 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:3970: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/819 [00:00<?, ? examples/s]
# Map:   0%|          | 0/818 [00:00<?, ? examples/s]

# %%
dataset_samsum_pt['train']
# Out:
# Dataset({
#     features: ['id', 'dialogue', 'summary', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 14732
# })

# %%
# Training

from transformers import DataCollatorForSeq2Seq

seq2seq_data_collator = DataCollatorForSeq2Seq(tokenizer, model=model_pegasus)

# %%
from transformers import TrainingArguments, Trainer

trainer_args = TrainingArguments(
    output_dir = "pegasus-samsum", num_train_epochs=1, warmup_steps = 500,
    per_device_train_batch_size = 1, per_device_eval_batch_size =1,
    weight_decay = 0.01, logging_steps=10,
    evaluation_strategy='steps', eval_steps=500, save_steps=1e6,
    gradient_accumulation_steps= 16
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer = Trainer(model= model_pegasus, args = trainer_args,
                  tokenizer= tokenizer, data_collator= seq2seq_data_collator,
                  train_dataset = dataset_samsum_pt['test'],
                  eval_dataset = dataset_samsum_pt["validation"]
                  )
# Out:
# <ipython-input-20-5a7fc5468241>:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(model= model_pegasus, args = trainer_args,

# %%
trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sujanlamichhane742 (sujanlamichhane742-lambton-college) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/content/wandb/run-20250306_204848-zez57rye</code>
# Syncing run <strong><a href='https://wandb.ai/sujanlamichhane742-lambton-college/huggingface/runs/zez57rye' target="_blank">pegasus-samsum</a></strong> to <a href='https://wandb.ai/sujanlamichhane742-lambton-college/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sujanlamichhane742-lambton-college/huggingface' target="_blank">https://wandb.ai/sujanlamichhane742-lambton-college/huggingface</a>
#  View run at <a href='https://wandb.ai/sujanlamichhane742-lambton-college/huggingface/runs/zez57rye' target="_blank">https://wandb.ai/sujanlamichhane742-lambton-college/huggingface/runs/zez57rye</a>
#     <div>
#
#       <progress value='51' max='51' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [51/51 03:20, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:2810: UserWarning: Moving the following attributes in the config to the generation config: {'max_length': 128, 'min_length': 32, 'num_beams': 8, 'length_penalty': 0.8}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# TrainOutput(global_step=51, training_loss=3.0044142264945832, metrics={'train_runtime': 364.9454, 'train_samples_per_second': 2.244, 'train_steps_per_second': 0.14, 'total_flos': 313450454089728.0, 'train_loss': 3.0044142264945832, 'epoch': 0.9963369963369964})

# %%
# Evaluation

def generate_batch_sized_chunks(list_of_elements, batch_size):
    """split the dataset into smaller batches that we can process simultaneously
    Yield successive batch-sized chunks from list_of_elements."""
    for i in range(0, len(list_of_elements), batch_size):
        yield list_of_elements[i : i + batch_size]



def calculate_metric_on_test_ds(dataset, metric, model, tokenizer,
                               batch_size=16, device=device,
                               column_text="article",
                               column_summary="highlights"):
    article_batches = list(generate_batch_sized_chunks(dataset[column_text], batch_size))
    target_batches = list(generate_batch_sized_chunks(dataset[column_summary], batch_size))

    for article_batch, target_batch in tqdm(
        zip(article_batches, target_batches), total=len(article_batches)):

        inputs = tokenizer(article_batch, max_length=1024,  truncation=True,
                        padding="max_length", return_tensors="pt")

        summaries = model.generate(input_ids=inputs["input_ids"].to(device),
                         attention_mask=inputs["attention_mask"].to(device),
                         length_penalty=0.8, num_beams=8, max_length=128)
        ''' parameter for length penalty ensures that the model does not generate sequences that are too long. '''

        # Finally, we decode the generated texts,
        # replace the  token, and add the decoded texts with the references to the metric.
        decoded_summaries = [tokenizer.decode(s, skip_special_tokens=True,
                                clean_up_tokenization_spaces=True)
               for s in summaries]

        decoded_summaries = [d.replace("", " ") for d in decoded_summaries]


        metric.add_batch(predictions=decoded_summaries, references=target_batch)

    #  Finally compute and return the ROUGE scores.
    score = metric.compute()
    return score

# %%
rouge_names = ["rouge1", "rouge2", "rougeL", "rougeLsum"]
rouge_metric = load_metrics('rouge')
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
score= calculate_metric_on_test_ds(
    dataset_samsum['test'][0:10], rouge_metric, trainer.model, tokenizer, batch_size = 2, column_text= "dialogue", column_summary = "summary"
)

rouge_dict = {rn: score[rn] for rn in rouge_names}
pd.DataFrame(rouge_dict, index = [f'pegasus'] )
# Out:
# 100%|██████████| 5/5 [00:18<00:00,  3.76s/it]
#            rouge1  rouge2    rougeL  rougeLsum
# pegasus  0.009942     0.0  0.009942   0.009914

# %%
##save model
model_pegasus.save_pretrained("pegasus-samsum-model")

# %%
##save_tokenizer
tokenizer.save_pretrained("tokenizer")
# Out:
# ('tokenizer/tokenizer_config.json',
#  'tokenizer/special_tokens_map.json',
#  'tokenizer/spiece.model',
#  'tokenizer/added_tokens.json',
#  'tokenizer/tokenizer.json')

# %%
#Load

tokenizer = AutoTokenizer.from_pretrained("/content/tokenizer")

# %%
#prediction

gen_kwargs = {"length_penalty": 0.8, "num_beams":8, "max_length":128}


sample_text = dataset_samsum["test"][0]["dialogue"]
reference = dataset_samsum["test"][0]["summary"]

pipe= pipeline("summarization", model = "pegasus-samsum-model", tokenizer=tokenizer)


##
print("Dialogue:")
print(sample_text)


print("\nReference Summary:")
print(reference)


print("\nModel Summary:")
print(pipe(sample_text, **gen_kwargs)[0]["summary_text"])
# Out:
# Device set to use cuda:0
# Your max_length is set to 128, but your input_length is only 122. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=61)
# Dialogue:
# Hannah: Hey, do you have Betty's number?
# Amanda: Lemme check
# Hannah: <file_gif>
# Amanda: Sorry, can't find it.
# Amanda: Ask Larry
# Amanda: He called her last time we were at the park together
# Hannah: I don't know him well
# Hannah: <file_gif>
# Amanda: Don't be shy, he's very nice
# Hannah: If you say so..
# Hannah: I'd rather you texted him
# Amanda: Just text him 🙂
# Hannah: Urgh.. Alright
# Hannah: Bye
# Amanda: Bye bye
#
# Reference Summary:
# Hannah needs Betty's number but Amanda doesn't have it. She needs to contact Larry.
#
# Model Summary:
# Amanda: Ask Larry Amanda: He called her last time we were at the park together .<n>Hannah: I'd rather you texted him .<n>Amanda: Just text him .
